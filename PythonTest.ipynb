# %% [markdown]
# <a href="https://colab.research.google.com/github/elaine15999/SQC_Cal/blob/main/PythonTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s_score = []
q_score = []
c_score = []

print('請逐筆輸入S細項分數')
for i in range(0, 12):          
    if i < 2:
        print('S'+ str(i+1),':')
    elif i>=2:
        if i<6:
            print('S3-'+str(i-1),':')
        elif i>=6:
            if i<9:
                print('S4-'+str(i-5),':')
            elif i>=9:
                print('S5-'+str(i-8),':')
    s_score.append(int(input()))

print('請逐筆輸入Q細項分數')
for i in range(0, 15):  
    if i==0:
        print('Q1 :')
    elif i>=1:
        if i<7:
            print('Q2-'+str(i),':')
        elif i>=7:
            if i<10:
                print('Q3-'+str(i-6),':')
            elif i>=10:
                if i<13:
                    print('Q4-'+str(i-9),':') 
                elif i>=13:
                    print('Q5-'+str(i-12),':') 
    q_score.append(int(input()))

print('請逐筆輸入C細項分數')
for i in range(0, 15):   
    if i<2:
        print('C1-'+str(i+1),':')
    elif i>=2:
        if i<8:
            print('C2-'+str(i-1),':')
        elif i>=8:
            if i<12:
                print('C3-'+str(i-7),':')
            elif i>=12:
                print('C4-'+str(i-11),':') 
                   
    c_score.append(int(input()))

print('S總分:'+ str(sum(s_score))+ '\nQ總分:'+ str(sum(q_score))+ '\nC總分:'+ str(sum(c_score)))
# Out:
# 請逐筆輸入S細項分數
# S1 :
# 10
# S2 :
# 10
# S3-1 :
# 10
# S3-2 :
# 10
# S3-3 :
# 10
# S3-4 :
# 10
# S4-1 :
# 10
# S4-2 :
# 10
# S4-3 :
# 10
# S5-1 :
# 10
# S5-2 :
# 10
# S5-3 :
# 10
# 請逐筆輸入Q細項分數
# Q1 :
# 1
# Q2-1 :
# 1
# Q2-2 :
# 1
# Q2-3 :
# 1
# Q2-4 :
# 1
# Q2-5 :
# 1
# Q2-6 :
# 1
# Q3-1 :
# 1
# Q3-2 :
# 1
# Q3-3 :
# 1
# Q4-1 :
# 1
# Q4-2 :
# 1
# Q4-3 :
# 1
# Q5-1 :
# 1
# Q5-2 :
# 1
# 請逐筆輸入C細項分數
# C1-1 :
# 5
# C1-2 :
# 5
# C2-1 :
# 5
# C2-2 :
# 5
# C2-3 :
# 5
# C2-4 :
# 5
# C2-5 :
# 5
# C2-6 :
# 5
# C3-1 :
# 5
# C3-2 :
# 5
# C3-3 :
# 5
# C3-4 :
# 5
# C4-1 :
# 5
# C4-2 :
# 5
# C4-3 :
# 5
# S總分:120
# Q總分:15
# C總分:75
